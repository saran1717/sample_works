# %%
import numpy as np

import matplotlib
from matplotlib import pyplot as plt

# %%
img=cv2.read("C:\Users\Lenovo\Desktop\Photo")
# Out:
#   File "<ipython-input-1-437b56166c6d>", line 1
#     img=cv2.read("C:\Users\Lenovo\Desktop\Photo")
#                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import cv2
img=cv2.imread('C:/Users/Lenovo/Desktop/Photo.jpg')
cv2.imshow('image',img)
cv2.waitkey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-b3f7ae071b85> in <module>
#       2 img=cv2.imread('C:/Users/Lenovo/Desktop/Photo.jpg')
#       3 cv2.imshow('image',img)
# ----> 4 cv2.waitkey(0)
#       5 cv2.destroyAllWindows()
#
# AttributeError: module 'cv2.cv2' has no attribute 'waitkey'

# %%
from PIL import Image
img=Image.open('./photo.jpg')
img.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-0a1be943b3a1> in <module>
#       1 from PIL import Image
# ----> 2 img=Image.open('./photo.jpg')
#       3 img.show()
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2889
#    2890     if filename:
# -> 2891         fp = builtins.open(filename, "rb")
#    2892         exclusive_fp = True
#    2893
#
# FileNotFoundError: [Errno 2] No such file or directory: './photo.jpg'

# %%
import matplotlib.pyplot as plt
img=cv2.imread('C:/Users/Lenovo/Desktop/photo.jpg')
plt.imshow(img)
