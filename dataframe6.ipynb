# %%
import pandas as pd
df=pd.read_excel(r'C:\Users\Lenovo\Desktop\Sample_Data.xlsx')
df
# Out:
#    Height  Weight  Last score  Score Grade
# 0     229      75          75     88     A
# 1     231      22          66     75     B
# 2     233     -31          57     62     C
# 3     235     -84          48     49     D
# 4     237    -137          39     36     A
# 5     239    -190          30     23     B
# 6     241    -243          21     10     C
# 7     243    -296          12     -3     D
# 8     245    -349           3    -16     A

# %%
df.columns
# Out:
# Index(['Height', 'Weight', 'Last score', 'Score', 'Grade'], dtype='object')

# %%
df.loc[0:2,'Weight':'Score']
# Out:
#    Weight  Last score  Score
# 0      75          75     88
# 1      22          66     75
# 2     -31          57     62

# %%
higher=(df['Height']>230) & (df['Score']>35)
df.loc[higher]
# Out:
#    Height  Weight  Last score  Score Grade
# 1     231      22          66     75     B
# 2     233     -31          57     62     C
# 3     235     -84          48     49     D
# 4     237    -137          39     36     A

# %%
df.loc[higher,['Height','Weight','Last score','Score','Grade']]
# Out:
#    Height  Weight  Last score  Score Grade
# 1     231      22          66     75     B
# 2     233     -31          57     62     C
# 3     235     -84          48     49     D
# 4     237    -137          39     36     A

# %%
df.columns=['Height','Weight','Last score','Score','Grade']
df
# Out:
#    Height  Weight  Last score  Score Grade
# 0     229      75          75     88     A
# 1     231      22          66     75     B
# 2     233     -31          57     62     C
# 3     235     -84          48     49     D
# 4     237    -137          39     36     A
# 5     239    -190          30     23     B
# 6     241    -243          21     10     C
# 7     243    -296          12     -3     D
# 8     245    -349           3    -16     A

# %%
df.columns=[x.upper() for x in df.columns]
df
# Out:
#    HEIGHT  WEIGHT  LAST SCORE  SCORE GRADE
# 0     229      75          75     88     A
# 1     231      22          66     75     B
# 2     233     -31          57     62     C
# 3     235     -84          48     49     D
# 4     237    -137          39     36     A
# 5     239    -190          30     23     B
# 6     241    -243          21     10     C
# 7     243    -296          12     -3     D
# 8     245    -349           3    -16     A

# %%
df.columns=df.columns.str.replace(' ','_')
df
# Out:
#    Height  Weight  Last_score  Score Grade
# 0     229      75          75     88     A
# 1     231      22          66     75     B
# 2     233     -31          57     62     C
# 3     235     -84          48     49     D
# 4     237    -137          39     36     A
# 5     239    -190          30     23     B
# 6     241    -243          21     10     C
# 7     243    -296          12     -3     D
# 8     245    -349           3    -16     A

# %%
df.rename(columns={'Height':'Hgt','Weight':'Wgt'},inplace=True)
df
# Out:
#    Hgt  Wgt  Last_score  Score Grade
# 0  229   75          75     88     A
# 1  231   22          66     75     B
# 2  233  -31          57     62     C
# 3  235  -84          48     49     D
# 4  237 -137          39     36     A
# 5  239 -190          30     23     B
# 6  241 -243          21     10     C
# 7  243 -296          12     -3     D
# 8  245 -349           3    -16     A

# %%
df.loc[2,'']
# Out:
# Hgt           233
# Wgt           -31
# Last_score     57
# Score          62
# Grade           C
# Name: 2, dtype: object
